# %% [markdown]
# # Part 4: Quantization

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
seed = 0
np.random.seed(seed)
import tensorflow as tf
tf.random.set_seed(seed)
import os
os.environ['PATH'] = '/opt/Xilinx/Vivado/2019.2/bin:' + os.environ['PATH']

# %% [markdown]
# ## Fetch the jet tagging dataset from Open ML

# %%
X_train_val = np.load('X_train_val.npy')
X_test = np.load('X_test.npy')
y_train_val = np.load('y_train_val.npy')
y_test = np.load('y_test.npy')
classes = np.load('classes.npy', allow_pickle=True)

# %% [markdown]
# ## Construct a model
# This time we're going to use QKeras layers.
# QKeras is "Quantized Keras" for deep heterogeneous quantization of ML models.
#
# https://github.com/google/qkeras
#
# It is maintained by Google and we recently added support for QKeras model to hls4ml.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1
from callbacks import all_callbacks
from tensorflow.keras.layers import Activation
from qkeras.qlayers import QDense, QActivation
from qkeras.quantizers import quantized_bits, quantized_relu

# %% [markdown]
# We're using `QDense` layer instead of `Dense`, and `QActivation` instead of `Activation`. We're also specifying `kernel_quantizer = quantized_bits(6,0,0)`. This will use 6-bits (of which 0 are integer) for the weights. We also use the same quantization for the biases, and `quantized_relu(6)` for 6-bit ReLU activations.

# %%
model = Sequential()
model.add(QDense(64, input_shape=(16,), name='fc1',
                 kernel_quantizer=quantized_bits(6,0,alpha=1), bias_quantizer=quantized_bits(6,0,alpha=1),
                 kernel_initializer='lecun_uniform', kernel_regularizer=l1(0.0001)))
model.add(QActivation(activation=quantized_relu(6), name='relu1'))
model.add(QDense(32, name='fc2',
                 kernel_quantizer=quantized_bits(6,0,alpha=1), bias_quantizer=quantized_bits(6,0,alpha=1),
                 kernel_initializer='lecun_uniform', kernel_regularizer=l1(0.0001)))
model.add(QActivation(activation=quantized_relu(6), name='relu2'))
model.add(QDense(32, name='fc3',
                 kernel_quantizer=quantized_bits(6,0,alpha=1), bias_quantizer=quantized_bits(6,0,alpha=1),
                 kernel_initializer='lecun_uniform', kernel_regularizer=l1(0.0001)))
model.add(QActivation(activation=quantized_relu(6), name='relu3'))
model.add(QDense(5, name='output',
                 kernel_quantizer=quantized_bits(6,0,alpha=1), bias_quantizer=quantized_bits(6,0,alpha=1),
                 kernel_initializer='lecun_uniform', kernel_regularizer=l1(0.0001)))
model.add(Activation(activation='softmax', name='softmax'))

# %% [markdown]
# ## Train sparse
# Let's train with model sparsity again, since QKeras layers are prunable.

# %%
from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning
pruning_params = {"pruning_schedule" : pruning_schedule.ConstantSparsity(0.75, begin_step=2000, frequency=100)}
model = prune.prune_low_magnitude(model, **pruning_params)
# Out:
# WARNING:tensorflow:From /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:200: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.

# %% [markdown]
# ## Train the model
# We'll use the same settings as the model for part 1: Adam optimizer with categorical crossentropy loss.
# The callbacks will decay the learning rate and save the model into a directory 'model_2'
# The model isn't very complex, so this should just take a few minutes even on the CPU.
# If you've restarted the notebook kernel after training once, set `train = False` to load the trained model rather than training again.

# %%
train = True
if train:
    adam = Adam(lr=0.0001)
    model.compile(optimizer=adam, loss=['categorical_crossentropy'], metrics=['accuracy'])
    callbacks = all_callbacks(stop_patience = 1000,
                              lr_factor = 0.5,
                              lr_patience = 10,
                              lr_epsilon = 0.000001,
                              lr_cooldown = 2,
                              lr_minimum = 0.0000001,
                              outputDir = 'model_3')
    callbacks.callbacks.append(pruning_callbacks.UpdatePruningStep())
    model.fit(X_train_val, y_train_val, batch_size=1024,
              epochs=30, validation_split=0.25, shuffle=True,
              callbacks = callbacks.callbacks)
    # Save the model again but with the pruning 'stripped' to use the regular layer types
    model = strip_pruning(model)
    model.save('model_3/KERAS_check_best_model.h5')
else:
    from tensorflow.keras.models import load_model
    from qkeras.utils import _add_supported_quantized_objects
    co = {}
    _add_supported_quantized_objects(co)
    model = load_model('model_3/KERAS_check_best_model.h5', custom_objects=co)
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Train on 498000 samples, validate on 166000 samples
# Epoch 1/30
# 496640/498000 [============================>.] - ETA: 0s - loss: 1.3864 - accuracy: 0.4904
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00001: val_loss improved from inf to 1.19412, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00001: val_loss improved from inf to 1.19412, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00001: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00001: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 10s 20us/sample - loss: 1.3859 - accuracy: 0.4907 - val_loss: 1.1941 - val_accuracy: 0.6036
# Epoch 2/30
# 497664/498000 [============================>.] - ETA: 0s - loss: 1.1092 - accuracy: 0.6521
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00002: val_loss improved from 1.19412 to 1.04901, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00002: val_loss improved from 1.19412 to 1.04901, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00002: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00002: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 1.1091 - accuracy: 0.6521 - val_loss: 1.0490 - val_accuracy: 0.6824
# Epoch 3/30
# 496640/498000 [============================>.] - ETA: 0s - loss: 1.0033 - accuracy: 0.7001
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00003: val_loss improved from 1.04901 to 0.96624, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00003: val_loss improved from 1.04901 to 0.96624, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00003: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00003: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 1.0032 - accuracy: 0.7002 - val_loss: 0.9662 - val_accuracy: 0.7122
# Epoch 4/30
# 495616/498000 [============================>.] - ETA: 0s - loss: 0.9330 - accuracy: 0.7172
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00004: val_loss improved from 0.96624 to 0.90940, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00004: val_loss improved from 0.96624 to 0.90940, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00004: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00004: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.9329 - accuracy: 0.7172 - val_loss: 0.9094 - val_accuracy: 0.7208
# Epoch 5/30
# 495616/498000 [============================>.] - ETA: 0s - loss: 1.1114 - accuracy: 0.6621
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00005: val_loss did not improve from 0.90940
#
# Epoch 00005: val_loss did not improve from 0.90940
#
# Epoch 00005: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00005: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 1.1111 - accuracy: 0.6623 - val_loss: 1.0602 - val_accuracy: 0.6896
# Epoch 6/30
# 496640/498000 [============================>.] - ETA: 0s - loss: 1.0163 - accuracy: 0.6999
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00006: val_loss did not improve from 0.90940
#
# Epoch 00006: val_loss did not improve from 0.90940
#
# Epoch 00006: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00006: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 13us/sample - loss: 1.0160 - accuracy: 0.7000 - val_loss: 0.9851 - val_accuracy: 0.7060
# Epoch 7/30
# 493568/498000 [============================>.] - ETA: 0s - loss: 0.9598 - accuracy: 0.7106
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00007: val_loss did not improve from 0.90940
#
# Epoch 00007: val_loss did not improve from 0.90940
#
# Epoch 00007: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00007: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 13us/sample - loss: 0.9597 - accuracy: 0.7106 - val_loss: 0.9405 - val_accuracy: 0.7133
# Epoch 8/30
# 494592/498000 [============================>.] - ETA: 0s - loss: 0.9242 - accuracy: 0.7161
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00008: val_loss did not improve from 0.90940
#
# Epoch 00008: val_loss did not improve from 0.90940
#
# Epoch 00008: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00008: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.9241 - accuracy: 0.7162 - val_loss: 0.9129 - val_accuracy: 0.7178
# Epoch 9/30
# 494592/498000 [============================>.] - ETA: 0s - loss: 0.8982 - accuracy: 0.7201
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00009: val_loss improved from 0.90940 to 0.89033, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00009: val_loss improved from 0.90940 to 0.89033, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00009: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00009: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.8982 - accuracy: 0.7201 - val_loss: 0.8903 - val_accuracy: 0.7211
# Epoch 10/30
# 496640/498000 [============================>.] - ETA: 0s - loss: 0.8774 - accuracy: 0.7232
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00010: val_loss improved from 0.89033 to 0.87090, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00010: val_loss improved from 0.89033 to 0.87090, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00010: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00010: saving model to model_3/KERAS_check_model_last_weights.h5
#
# Epoch 00010: saving model to model_3/KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.8775 - accuracy: 0.7232 - val_loss: 0.8709 - val_accuracy: 0.7238
# Epoch 11/30
# 493568/498000 [============================>.] - ETA: 0s - loss: 0.8593 - accuracy: 0.7262
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00011: val_loss improved from 0.87090 to 0.85364, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00011: val_loss improved from 0.87090 to 0.85364, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00011: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00011: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.8594 - accuracy: 0.7262 - val_loss: 0.8536 - val_accuracy: 0.7263
# Epoch 12/30
# 497664/498000 [============================>.] - ETA: 0s - loss: 0.8433 - accuracy: 0.7289
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00012: val_loss improved from 0.85364 to 0.83962, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00012: val_loss improved from 0.85364 to 0.83962, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00012: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00012: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 15us/sample - loss: 0.8433 - accuracy: 0.7289 - val_loss: 0.8396 - val_accuracy: 0.7286
# Epoch 13/30
# 495616/498000 [============================>.] - ETA: 0s - loss: 0.8294 - accuracy: 0.7310
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00013: val_loss improved from 0.83962 to 0.82617, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00013: val_loss improved from 0.83962 to 0.82617, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00013: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00013: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 13us/sample - loss: 0.8295 - accuracy: 0.7310 - val_loss: 0.8262 - val_accuracy: 0.7306
# Epoch 14/30
# 496640/498000 [============================>.] - ETA: 0s - loss: 0.8179 - accuracy: 0.7327
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00014: val_loss improved from 0.82617 to 0.81604, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00014: val_loss improved from 0.82617 to 0.81604, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00014: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00014: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.8179 - accuracy: 0.7327 - val_loss: 0.8160 - val_accuracy: 0.7326
# Epoch 15/30
# 496640/498000 [============================>.] - ETA: 0s - loss: 0.8082 - accuracy: 0.7344
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00015: val_loss improved from 0.81604 to 0.80758, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00015: val_loss improved from 0.81604 to 0.80758, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00015: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00015: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.8083 - accuracy: 0.7344 - val_loss: 0.8076 - val_accuracy: 0.7338
# Epoch 16/30
# 496640/498000 [============================>.] - ETA: 0s - loss: 0.7998 - accuracy: 0.7359
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00016: val_loss improved from 0.80758 to 0.80006, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00016: val_loss improved from 0.80758 to 0.80006, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00016: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00016: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.7998 - accuracy: 0.7359 - val_loss: 0.8001 - val_accuracy: 0.7356
# Epoch 17/30
# 497664/498000 [============================>.] - ETA: 0s - loss: 0.7926 - accuracy: 0.7372
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00017: val_loss improved from 0.80006 to 0.79343, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00017: val_loss improved from 0.80006 to 0.79343, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00017: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00017: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.7926 - accuracy: 0.7372 - val_loss: 0.7934 - val_accuracy: 0.7376
# Epoch 18/30
# 496640/498000 [============================>.] - ETA: 0s - loss: 0.7870 - accuracy: 0.7385
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00018: val_loss improved from 0.79343 to 0.78801, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00018: val_loss improved from 0.79343 to 0.78801, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00018: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00018: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.7870 - accuracy: 0.7385 - val_loss: 0.7880 - val_accuracy: 0.7386
# Epoch 19/30
# 493568/498000 [============================>.] - ETA: 0s - loss: 0.7815 - accuracy: 0.7398
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00019: val_loss improved from 0.78801 to 0.78331, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00019: val_loss improved from 0.78801 to 0.78331, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00019: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00019: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.7814 - accuracy: 0.7399 - val_loss: 0.7833 - val_accuracy: 0.7397
# Epoch 20/30
# 496640/498000 [============================>.] - ETA: 0s - loss: 0.7769 - accuracy: 0.7411
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00020: val_loss improved from 0.78331 to 0.77986, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00020: val_loss improved from 0.78331 to 0.77986, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00020: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00020: saving model to model_3/KERAS_check_model_last_weights.h5
#
# Epoch 00020: saving model to model_3/KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.7770 - accuracy: 0.7411 - val_loss: 0.7799 - val_accuracy: 0.7405
# Epoch 21/30
# 496640/498000 [============================>.] - ETA: 0s - loss: 0.7735 - accuracy: 0.7418
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00021: val_loss improved from 0.77986 to 0.77579, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00021: val_loss improved from 0.77986 to 0.77579, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00021: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00021: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.7734 - accuracy: 0.7418 - val_loss: 0.7758 - val_accuracy: 0.7410
# Epoch 22/30
# 494592/498000 [============================>.] - ETA: 0s - loss: 0.7698 - accuracy: 0.7426
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00022: val_loss improved from 0.77579 to 0.77217, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00022: val_loss improved from 0.77579 to 0.77217, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00022: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00022: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.7699 - accuracy: 0.7426 - val_loss: 0.7722 - val_accuracy: 0.7425
# Epoch 23/30
# 496640/498000 [============================>.] - ETA: 0s - loss: 0.7663 - accuracy: 0.7435
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00023: val_loss improved from 0.77217 to 0.76974, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00023: val_loss improved from 0.77217 to 0.76974, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00023: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00023: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.7664 - accuracy: 0.7435 - val_loss: 0.7697 - val_accuracy: 0.7429
# Epoch 24/30
# 495616/498000 [============================>.] - ETA: 0s - loss: 0.7634 - accuracy: 0.7443
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00024: val_loss improved from 0.76974 to 0.76685, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00024: val_loss improved from 0.76974 to 0.76685, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00024: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00024: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 13us/sample - loss: 0.7634 - accuracy: 0.7443 - val_loss: 0.7669 - val_accuracy: 0.7435
# Epoch 25/30
# 495616/498000 [============================>.] - ETA: 0s - loss: 0.7610 - accuracy: 0.7450
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00025: val_loss improved from 0.76685 to 0.76440, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00025: val_loss improved from 0.76685 to 0.76440, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00025: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00025: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.7611 - accuracy: 0.7449 - val_loss: 0.7644 - val_accuracy: 0.7441
# Epoch 26/30
# 497664/498000 [============================>.] - ETA: 0s - loss: 0.7589 - accuracy: 0.7454
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00026: val_loss improved from 0.76440 to 0.76275, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00026: val_loss improved from 0.76440 to 0.76275, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00026: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00026: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.7589 - accuracy: 0.7454 - val_loss: 0.7627 - val_accuracy: 0.7445
# Epoch 27/30
# 497664/498000 [============================>.] - ETA: 0s - loss: 0.7574 - accuracy: 0.7458
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00027: val_loss improved from 0.76275 to 0.76076, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00027: val_loss improved from 0.76275 to 0.76076, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00027: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00027: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.7574 - accuracy: 0.7458 - val_loss: 0.7608 - val_accuracy: 0.7451
# Epoch 28/30
# 493568/498000 [============================>.] - ETA: 0s - loss: 0.7555 - accuracy: 0.7464
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00028: val_loss improved from 0.76076 to 0.75986, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00028: val_loss improved from 0.76076 to 0.75986, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00028: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00028: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 13us/sample - loss: 0.7554 - accuracy: 0.7465 - val_loss: 0.7599 - val_accuracy: 0.7455
# Epoch 29/30
# 494592/498000 [============================>.] - ETA: 0s - loss: 0.7536 - accuracy: 0.7469
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00029: val_loss improved from 0.75986 to 0.75769, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00029: val_loss improved from 0.75986 to 0.75769, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00029: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00029: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.7537 - accuracy: 0.7468 - val_loss: 0.7577 - val_accuracy: 0.7461
# Epoch 30/30
# 494592/498000 [============================>.] - ETA: 0s - loss: 0.7522 - accuracy: 0.7472
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00030: val_loss improved from 0.75769 to 0.75733, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00030: val_loss improved from 0.75769 to 0.75733, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00030: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00030: saving model to model_3/KERAS_check_model_last_weights.h5
#
# Epoch 00030: saving model to model_3/KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 7s 14us/sample - loss: 0.7523 - accuracy: 0.7472 - val_loss: 0.7573 - val_accuracy: 0.7465

# %% [markdown]
# ## Check performance
# How does this model which was trained using 6-bits, and 75% sparsity model compare against the original model? Let's report the accuracy and make a ROC curve. The quantized, pruned model is shown with solid lines, the unpruned model from part 1 is shown with dashed lines.
#
#
# We should also check that hls4ml can respect the choice to use 6-bits throughout the model, and match the accuracy. We'll generate a configuration from this Quantized model, and plot its performance as the dotted line.
# The generated configuration is printed out. You'll notice that it uses 7 bits for the type, but we specified 6!? That's just because QKeras doesn't count the sign-bit when we specify the number of bits, so the type that actually gets used needs 1 more.
#
# We also use the `OutputRoundingSaturationMode` optimizer pass of `hls4ml` to set the Activation layers to round, rather than truncate, the cast. This is important for getting good model accuracy when using small bit precision activations. And we'll set a different data type for the tables used in the Softmax, just for a bit of extra performance.
#
#
# **Make sure you've trained the model from part 1**

# %%
import hls4ml
import plotting
hls4ml.model.optimizer.OutputRoundingSaturationMode.layers = ['Activation']
hls4ml.model.optimizer.OutputRoundingSaturationMode.rounding_mode = 'AP_RND'
hls4ml.model.optimizer.OutputRoundingSaturationMode.saturation_mode = 'AP_SAT'

config = hls4ml.utils.config_from_keras_model(model, granularity='name')
config['LayerName']['softmax']['exp_table_t'] = 'ap_fixed<18,8>'
config['LayerName']['softmax']['inv_table_t'] = 'ap_fixed<18,4>'
print("-----------------------------------")
plotting.print_dict(config)
print("-----------------------------------")
hls_model = hls4ml.converters.convert_from_keras_model(model,
                                                       hls_config=config,
                                                       output_dir='model_3/hls4ml_prj',
                                                       fpga_part='xcu250-figd2104-2L-e')
hls_model.compile()

y_qkeras = model.predict(X_test)
y_hls = hls_model.predict(X_test)
# Out:
# Interpreting Sequential
# Topology:
# Layer name: fc1, layer type: QDense
# Layer name: relu1, layer type: QActivation
# Layer name: fc2, layer type: QDense
# Layer name: relu2, layer type: QActivation
# Layer name: fc3, layer type: QDense
# Layer name: relu3, layer type: QActivation
# Layer name: output, layer type: QDense
# Layer name: softmax, layer type: Activation
# -----------------------------------
# LayerName
#   fc1
#     Precision
#       weight:        ap_fixed<7,1>
#       bias:          ap_fixed<7,1>
#     ReuseFactor:     1
#   relu1
#     Precision
#       result:        ap_fixed<7,1>
#     ReuseFactor:     1
#   fc2
#     Precision
#       weight:        ap_fixed<7,1>
#       bias:          ap_fixed<7,1>
#     ReuseFactor:     1
#   relu2
#     Precision
#       result:        ap_fixed<7,1>
#     ReuseFactor:     1
#   fc3
#     Precision
#       weight:        ap_fixed<7,1>
#       bias:          ap_fixed<7,1>
#     ReuseFactor:     1
#   relu3
#     Precision
#       result:        ap_fixed<7,1>
#     ReuseFactor:     1
#   output
#     Precision
#       weight:        ap_fixed<7,1>
#       bias:          ap_fixed<7,1>
#     ReuseFactor:     1
#   softmax
#     Precision:       ap_fixed<16,6>
#     ReuseFactor:     1
#     table_size:      1024
#     table_t:         ap_fixed<18,8>
#     exp_table_t:     ap_fixed<18,8>
#     inv_table_t:     ap_fixed<18,4>
# -----------------------------------
# Interpreting Sequential
# Input shape: [16]
# Topology:
# Layer name: fc1, layer type: QDense, current shape: [[None, 16]]
# Layer name: relu1, layer type: Activation, current shape: [[None, 64]]
# Layer name: fc2, layer type: QDense, current shape: [[None, 64]]
# Layer name: relu2, layer type: Activation, current shape: [[None, 32]]
# Layer name: fc3, layer type: QDense, current shape: [[None, 32]]
# Layer name: relu3, layer type: Activation, current shape: [[None, 32]]
# Layer name: output, layer type: QDense, current shape: [[None, 32]]
# Layer name: softmax, layer type: Softmax, current shape: [[None, 5]]
# Creating HLS model
# Writing HLS project
# Done

# %%
# %matplotlib inline
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model

model_ref = load_model('model_1/KERAS_check_best_model.h5')
y_ref = model_ref.predict(X_test)

print("Accuracy baseline:  {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_ref, axis=1))))
print("Accuracy pruned, quantized: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_qkeras, axis=1))))
print("Accuracy hls4ml: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_hls, axis=1))))

fig, ax = plt.subplots(figsize=(9, 9))
_ = plotting.makeRoc(y_test, y_ref, classes)
plt.gca().set_prop_cycle(None) # reset the colors
_ = plotting.makeRoc(y_test, y_qkeras, classes, linestyle='--')
plt.gca().set_prop_cycle(None) # reset the colors
_ = plotting.makeRoc(y_test, y_hls, classes, linestyle=':')

from matplotlib.lines import Line2D
lines = [Line2D([0], [0], ls='-'),
         Line2D([0], [0], ls='--'),
         Line2D([0], [0], ls=':')]
from matplotlib.legend import Legend
leg = Legend(ax, lines, labels=['baseline', 'pruned, quantized', 'hls4ml'],
            loc='lower right', frameon=False)
ax.add_artist(leg)
# Out:
# Accuracy baseline:  0.7501024096385542
# Accuracy pruned, quantized: 0.7446144578313253
# Accuracy hls4ml: 0.7445060240963856

# %% [markdown]
# # Synthesize
# Now let's synthesize this quantized, pruned model.
#
# **The synthesis will take a while**
#
# While the C-Synthesis is running, we can monitor the progress looking at the log file by opening a terminal from the notebook home, and executing:
#
# `tail -f model_3/hls4ml_prj/vivado_hls.log`

# %%
hls_model.build(csim=False)

# %% [markdown]
# ## Check the reports
# Print out the reports generated by Vivado HLS. Pay attention to the Utilization Estimates' section in particular this time.

# %%
hls4ml.report.read_vivado_report('model_3/hls4ml_prj')
# Out:
# Found 1 solution(s) in model_3/hls4ml_prj/myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject'
# ================================================================
# * Date:           Fri Sep  4 10:35:35 2020
#
# * Version:        2019.2 (Build 2704478 on Wed Nov 06 22:10:23 MST 2019)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: virtexuplus
# * Target device:  xcu250-figd2104-2L-e
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing:
#     * Summary:
#     +--------+---------+----------+------------+
#     |  Clock |  Target | Estimated| Uncertainty|
#     +--------+---------+----------+------------+
#     |ap_clk  | 5.00 ns | 4.297 ns |   0.62 ns  |
#     +--------+---------+----------+------------+
#
# + Latency:
#     * Summary:
#     +---------+---------+-----------+-----------+-----+-----+----------+
#     |  Latency (cycles) |   Latency (absolute)  |  Interval | Pipeline |
#     |   min   |   max   |    min    |    max    | min | max |   Type   |
#     +---------+---------+-----------+-----------+-----+-----+----------+
#     |       11|       11| 55.000 ns | 55.000 ns |    1|    1| function |
#     +---------+---------+-----------+-----------+-----+-----+----------+
#
#     + Detail:
#         * Instance:
#         +----------------------------------------+-----------------------+---------+---------+----------+----------+-----+-----+----------+
#         |                                        |                       |  Latency (cycles) |  Latency (absolute) |  Interval | Pipeline |
#         |                Instance                |         Module        |   min   |   max   |    min   |    max   | min | max |   Type   |
#         +----------------------------------------+-----------------------+---------+---------+----------+----------+-----+-----+----------+
#         |grp_dense_latency_0_0_0_1_fu_215        |dense_latency_0_0_0_1  |        1|        1| 5.000 ns | 5.000 ns |    1|    1| function |
#         |grp_dense_latency_0_0_0_s_fu_283        |dense_latency_0_0_0_s  |        1|        1| 5.000 ns | 5.000 ns |    1|    1| function |
#         |grp_dense_latency_0_0_0_3_fu_319        |dense_latency_0_0_0_3  |        1|        1| 5.000 ns | 5.000 ns |    1|    1| function |
#         |call_ret1_relu_1_fu_325                 |relu_1                 |        0|        0|   0 ns   |   0 ns   |    1|    1| function |
#         |call_ret6_dense_latency_0_0_0_2_fu_393  |dense_latency_0_0_0_2  |        0|        0|   0 ns   |   0 ns   |    1|    1| function |
#         |call_ret3_relu_fu_429                   |relu                   |        0|        0|   0 ns   |   0 ns   |    1|    1| function |
#         |call_ret5_relu_2_fu_465                 |relu_2                 |        0|        0|   0 ns   |   0 ns   |    1|    1| function |
#         +----------------------------------------+-----------------------+---------+---------+----------+----------+-----+-----+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +---------------------+---------+-------+---------+---------+------+
# |         Name        | BRAM_18K| DSP48E|    FF   |   LUT   | URAM |
# +---------------------+---------+-------+---------+---------+------+
# |DSP                  |        -|      5|        -|        -|     -|
# |Expression           |        -|      -|        0|       78|     -|
# |FIFO                 |        -|      -|        -|        -|     -|
# |Instance             |        -|    216|     5697|    77665|     -|
# |Memory               |        4|      -|        0|        0|     -|
# |Multiplexer          |        -|      -|        -|       36|     -|
# |Register             |        -|      -|     3129|        -|     -|
# +---------------------+---------+-------+---------+---------+------+
# |Total                |        4|    221|     8826|    77779|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available SLR        |     1344|   3072|   864000|   432000|   320|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization SLR (%)  |    ~0   |      7|        1|       18|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available            |     5376|  12288|  3456000|  1728000|  1280|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization (%)      |    ~0   |      1|    ~0   |        4|     0|
# +---------------------+---------+-------+---------+---------+------+
#
# + Detail:
#     * Instance:
#     +----------------------------------------+-----------------------+---------+-------+------+-------+-----+
#     |                Instance                |         Module        | BRAM_18K| DSP48E|  FF  |  LUT  | URAM|
#     +----------------------------------------+-----------------------+---------+-------+------+-------+-----+
#     |grp_dense_latency_0_0_0_1_fu_215        |dense_latency_0_0_0_1  |        0|      0|  1511|  35113|    0|
#     |call_ret6_dense_latency_0_0_0_2_fu_393  |dense_latency_0_0_0_2  |        0|      0|     0|   3955|    0|
#     |grp_dense_latency_0_0_0_3_fu_319        |dense_latency_0_0_0_3  |        0|    216|  3425|  11792|    0|
#     |grp_dense_latency_0_0_0_s_fu_283        |dense_latency_0_0_0_s  |        0|      0|   761|  17845|    0|
#     |call_ret3_relu_fu_429                   |relu                   |        0|      0|     0|   2240|    0|
#     |call_ret1_relu_1_fu_325                 |relu_1                 |        0|      0|     0|   4480|    0|
#     |call_ret5_relu_2_fu_465                 |relu_2                 |        0|      0|     0|   2240|    0|
#     +----------------------------------------+-----------------------+---------+-------+------+-------+-----+
#     |Total                                   |                       |        0|    216|  5697|  77665|    0|
#     +----------------------------------------+-----------------------+---------+-------+------+-------+-----+

# %% [markdown]
# Print the report for the model trained in part 1. Now, compared to the model from part 1, this model has been trained with low-precision quantization, and 75% pruning. You should be able to see that we have saved a lot of resource compared to where we started in part 1. At the same time, referring to the ROC curve above, the model performance is pretty much identical even with this drastic compression!
#
# **Note you need to have trained and synthesized the model from part 1**

# %%
hls4ml.report.read_vivado_report('model_1/hls4ml_prj')
# Out:
# Found 1 solution(s) in model_1/hls4ml_prj/myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject'
# ================================================================
# * Date:           Fri Sep  4 08:47:39 2020
#
# * Version:        2019.2 (Build 2704478 on Wed Nov 06 22:10:23 MST 2019)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: virtexuplus
# * Target device:  xcu250-figd2104-2L-e
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing:
#     * Summary:
#     +--------+---------+----------+------------+
#     |  Clock |  Target | Estimated| Uncertainty|
#     +--------+---------+----------+------------+
#     |ap_clk  | 5.00 ns | 3.883 ns |   0.62 ns  |
#     +--------+---------+----------+------------+
#
# + Latency:
#     * Summary:
#     +---------+---------+-----------+-----------+-----+-----+----------+
#     |  Latency (cycles) |   Latency (absolute)  |  Interval | Pipeline |
#     |   min   |   max   |    min    |    max    | min | max |   Type   |
#     +---------+---------+-----------+-----------+-----+-----+----------+
#     |        9|        9| 45.000 ns | 45.000 ns |    1|    1| function |
#     +---------+---------+-----------+-----------+-----+-----+----------+
#
#     + Detail:
#         * Instance:
#         +----------------------------------+-----------------------+---------+---------+----------+----------+-----+-----+----------+
#         |                                  |                       |  Latency (cycles) |  Latency (absolute) |  Interval | Pipeline |
#         |             Instance             |         Module        |   min   |   max   |    min   |    max   | min | max |   Type   |
#         +----------------------------------+-----------------------+---------+---------+----------+----------+-----+-----+----------+
#         |grp_dense_latency_0_0_0_1_fu_215  |dense_latency_0_0_0_1  |        1|        1| 5.000 ns | 5.000 ns |    1|    1| function |
#         |grp_dense_latency_0_0_0_s_fu_283  |dense_latency_0_0_0_s  |        1|        1| 5.000 ns | 5.000 ns |    1|    1| function |
#         |grp_dense_latency_0_0_0_2_fu_319  |dense_latency_0_0_0_2  |        1|        1| 5.000 ns | 5.000 ns |    1|    1| function |
#         |grp_dense_latency_0_0_0_3_fu_325  |dense_latency_0_0_0_3  |        1|        1| 5.000 ns | 5.000 ns |    1|    1| function |
#         |call_ret1_relu_1_fu_361           |relu_1                 |        0|        0|   0 ns   |   0 ns   |    1|    1| function |
#         |call_ret3_relu_fu_429             |relu                   |        0|        0|   0 ns   |   0 ns   |    1|    1| function |
#         |call_ret5_relu_2_fu_465           |relu_2                 |        0|        0|   0 ns   |   0 ns   |    1|    1| function |
#         +----------------------------------+-----------------------+---------+---------+----------+----------+-----+-----+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +---------------------+---------+-------+---------+---------+------+
# |         Name        | BRAM_18K| DSP48E|    FF   |   LUT   | URAM |
# +---------------------+---------+-------+---------+---------+------+
# |DSP                  |        -|      5|        -|        -|     -|
# |Expression           |        -|      -|        0|       78|     -|
# |FIFO                 |        -|      -|        -|        -|     -|
# |Instance             |        -|   3948|    24516|    78497|     -|
# |Memory               |        4|      -|        0|        0|     -|
# |Multiplexer          |        -|      -|        -|       36|     -|
# |Register             |        -|      -|     2405|        -|     -|
# +---------------------+---------+-------+---------+---------+------+
# |Total                |        4|   3953|    26921|    78611|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available SLR        |     1344|   3072|   864000|   432000|   320|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization SLR (%)  |    ~0   |    128|        3|       18|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available            |     5376|  12288|  3456000|  1728000|  1280|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization (%)      |    ~0   |     32|    ~0   |        4|     0|
# +---------------------+---------+-------+---------+---------+------+
#
# + Detail:
#     * Instance:
#     +----------------------------------+-----------------------+---------+-------+-------+-------+-----+
#     |             Instance             |         Module        | BRAM_18K| DSP48E|   FF  |  LUT  | URAM|
#     +----------------------------------+-----------------------+---------+-------+-------+-------+-----+
#     |grp_dense_latency_0_0_0_1_fu_215  |dense_latency_0_0_0_1  |        0|   1858|  11265|  35808|    0|
#     |grp_dense_latency_0_0_0_2_fu_319  |dense_latency_0_0_0_2  |        0|    983|   6145|  18240|    0|
#     |grp_dense_latency_0_0_0_3_fu_325  |dense_latency_0_0_0_3  |        0|    160|    961|   2825|    0|
#     |grp_dense_latency_0_0_0_s_fu_283  |dense_latency_0_0_0_s  |        0|    947|   6145|  18040|    0|
#     |call_ret3_relu_fu_429             |relu                   |        0|      0|      0|    896|    0|
#     |call_ret1_relu_1_fu_361           |relu_1                 |        0|      0|      0|   1792|    0|
#     |call_ret5_relu_2_fu_465           |relu_2                 |        0|      0|      0|    896|    0|
#     +----------------------------------+-----------------------+---------+-------+-------+-------+-----+
#     |Total                             |                       |        0|   3948|  24516|  78497|    0|
#     +----------------------------------+-----------------------+---------+-------+-------+-------+-----+

# %% [markdown]
# Print the report for the model trained in part 3. Both these models were trained with 75% sparsity, but the new model uses 6-bit precision as well. You can see how Vivado HLS has moved multiplication operations from DSPs into LUTs, reducing the "critical" resource usage.
#
# **Note you need to have trained and synthesized the model from part 3**

# %%
hls4ml.report.read_vivado_report('model_2/hls4ml_prj')
# Out:
# Found 1 solution(s) in model_2/hls4ml_prj/myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject'
# ================================================================
# * Date:           Fri Sep  4 09:51:03 2020
#
# * Version:        2019.2 (Build 2704478 on Wed Nov 06 22:10:23 MST 2019)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: virtexuplus
# * Target device:  xcu250-figd2104-2L-e
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing:
#     * Summary:
#     +--------+---------+----------+------------+
#     |  Clock |  Target | Estimated| Uncertainty|
#     +--------+---------+----------+------------+
#     |ap_clk  | 5.00 ns | 4.276 ns |   0.62 ns  |
#     +--------+---------+----------+------------+
#
# + Latency:
#     * Summary:
#     +---------+---------+-----------+-----------+-----+-----+----------+
#     |  Latency (cycles) |   Latency (absolute)  |  Interval | Pipeline |
#     |   min   |   max   |    min    |    max    | min | max |   Type   |
#     +---------+---------+-----------+-----------+-----+-----+----------+
#     |       16|       16| 80.000 ns | 80.000 ns |    2|    2| function |
#     +---------+---------+-----------+-----------+-----+-----+----------+
#
#     + Detail:
#         * Instance:
#         +----------------------------------+-----------------------+---------+---------+-----------+-----------+-----+-----+----------+
#         |                                  |                       |  Latency (cycles) |   Latency (absolute)  |  Interval | Pipeline |
#         |             Instance             |         Module        |   min   |   max   |    min    |    max    | min | max |   Type   |
#         +----------------------------------+-----------------------+---------+---------+-----------+-----------+-----+-----+----------+
#         |grp_dense_latency_0_0_0_1_fu_207  |dense_latency_0_0_0_1  |        2|        2| 10.000 ns | 10.000 ns |    2|    2| function |
#         |grp_dense_latency_0_0_0_s_fu_275  |dense_latency_0_0_0_s  |        2|        2| 10.000 ns | 10.000 ns |    2|    2| function |
#         |grp_dense_latency_0_0_0_2_fu_311  |dense_latency_0_0_0_2  |        1|        1|  5.000 ns |  5.000 ns |    2|    2| function |
#         |grp_dense_latency_0_0_0_3_fu_317  |dense_latency_0_0_0_3  |        2|        2| 10.000 ns | 10.000 ns |    2|    2| function |
#         |call_ret1_relu_1_fu_353           |relu_1                 |        0|        0|    0 ns   |    0 ns   |    1|    1| function |
#         |call_ret3_relu_fu_421             |relu                   |        0|        0|    0 ns   |    0 ns   |    1|    1| function |
#         |call_ret5_relu_2_fu_457           |relu_2                 |        0|        0|    0 ns   |    0 ns   |    1|    1| function |
#         +----------------------------------+-----------------------+---------+---------+-----------+-----------+-----+-----+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +---------------------+---------+-------+---------+---------+------+
# |         Name        | BRAM_18K| DSP48E|    FF   |   LUT   | URAM |
# +---------------------+---------+-------+---------+---------+------+
# |DSP                  |        -|      5|        -|        -|     -|
# |Expression           |        -|      -|        0|       78|     -|
# |FIFO                 |        -|      -|        -|        -|     -|
# |Instance             |        -|   1064|    17470|    57002|     -|
# |Memory               |        3|      -|        0|        0|     -|
# |Multiplexer          |        -|      -|        -|       99|     -|
# |Register             |        -|      -|     3991|        -|     -|
# +---------------------+---------+-------+---------+---------+------+
# |Total                |        3|   1069|    21461|    57179|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available SLR        |     1344|   3072|   864000|   432000|   320|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization SLR (%)  |    ~0   |     34|        2|       13|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available            |     5376|  12288|  3456000|  1728000|  1280|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization (%)      |    ~0   |      8|    ~0   |        3|     0|
# +---------------------+---------+-------+---------+---------+------+
#
# + Detail:
#     * Instance:
#     +----------------------------------+-----------------------+---------+-------+------+-------+-----+
#     |             Instance             |         Module        | BRAM_18K| DSP48E|  FF  |  LUT  | URAM|
#     +----------------------------------+-----------------------+---------+-------+------+-------+-----+
#     |grp_dense_latency_0_0_0_1_fu_207  |dense_latency_0_0_0_1  |        0|    512|  8772|  25264|    0|
#     |grp_dense_latency_0_0_0_2_fu_311  |dense_latency_0_0_0_2  |        0|    256|  3154|  12833|    0|
#     |grp_dense_latency_0_0_0_3_fu_317  |dense_latency_0_0_0_3  |        0|     40|  1124|   2985|    0|
#     |grp_dense_latency_0_0_0_s_fu_275  |dense_latency_0_0_0_s  |        0|    256|  4420|  12336|    0|
#     |call_ret3_relu_fu_421             |relu                   |        0|      0|     0|    896|    0|
#     |call_ret1_relu_1_fu_353           |relu_1                 |        0|      0|     0|   1792|    0|
#     |call_ret5_relu_2_fu_457           |relu_2                 |        0|      0|     0|    896|    0|
#     +----------------------------------+-----------------------+---------+-------+------+-------+-----+
#     |Total                             |                       |        0|   1064| 17470|  57002|    0|
#     +----------------------------------+-----------------------+---------+-------+------+-------+-----+

# %% [markdown]
# ## NB
# Note as well that the Vivado HLS resource estimates tend to _overestimate_ LUTs, while generally estimating the DSPs correctly. Running the subsequent stages of FPGA compilation reveals the more realistic resource usage, You can run the next step, 'logic synthesis' with `hls_model.build(synth=True, vsynth=True)`, but we skipped it in this tutorial in the interest of time.

# %%
hls_model.build(synth=True, vsynth=True)
