# %% [markdown]
# # Part 3: Compression

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
seed = 0
np.random.seed(seed)
import tensorflow as tf
tf.random.set_seed(seed)
import os
os.environ['PATH'] = '/opt/Xilinx/Vivado/2019.2/bin:' + os.environ['PATH']

# %% [markdown]
# ## Fetch the jet tagging dataset from Open ML

# %%
X_train_val = np.load('X_train_val.npy')
X_test = np.load('X_test.npy')
y_train_val = np.load('y_train_val.npy')
y_test = np.load('y_test.npy')
classes = np.load('classes.npy', allow_pickle=True)

# %% [markdown]
# ## Now construct a model
# We'll use the same architecture as in part 1: 3 hidden layers with 64, then 32, then 32 neurons. Each layer will use `relu` activation.
# Add an output layer with 5 neurons (one for each class), then finish with Softmax activation.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1
from callbacks import all_callbacks

# %%
model = Sequential()
model.add(Dense(64, input_shape=(16,), name='fc1', kernel_initializer='lecun_uniform', kernel_regularizer=l1(0.0001)))
model.add(Activation(activation='relu', name='relu1'))
model.add(Dense(32, name='fc2', kernel_initializer='lecun_uniform', kernel_regularizer=l1(0.0001)))
model.add(Activation(activation='relu', name='relu2'))
model.add(Dense(32, name='fc3', kernel_initializer='lecun_uniform', kernel_regularizer=l1(0.0001)))
model.add(Activation(activation='relu', name='relu3'))
model.add(Dense(5, name='output', kernel_initializer='lecun_uniform', kernel_regularizer=l1(0.0001)))
model.add(Activation(activation='softmax', name='softmax'))

# %% [markdown]
# ## Train sparse
# This time we'll use the Tensorflow model optimization sparsity to train a sparse model (forcing many weights to '0'). In this instance, the target sparsity is 75%

# %%
from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning
pruning_params = {"pruning_schedule" : pruning_schedule.ConstantSparsity(0.75, begin_step=2000, frequency=100)}
model = prune.prune_low_magnitude(model, **pruning_params)
# Out:
# WARNING:tensorflow:From /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:200: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.

# %% [markdown]
# ## Train the model
# We'll use the same settings as the model for part 1: Adam optimizer with categorical crossentropy loss.
# The callbacks will decay the learning rate and save the model into a directory 'model_2'
# The model isn't very complex, so this should just take a few minutes even on the CPU.
# If you've restarted the notebook kernel after training once, set `train = False` to load the trained model rather than training again.

# %%
train = True
if train:
    adam = Adam(lr=0.0001)
    model.compile(optimizer=adam, loss=['categorical_crossentropy'], metrics=['accuracy'])
    callbacks = all_callbacks(stop_patience = 1000,
                              lr_factor = 0.5,
                              lr_patience = 10,
                              lr_epsilon = 0.000001,
                              lr_cooldown = 2,
                              lr_minimum = 0.0000001,
                              outputDir = 'model_2')
    callbacks.callbacks.append(pruning_callbacks.UpdatePruningStep())
    model.fit(X_train_val, y_train_val, batch_size=1024,
              epochs=30, validation_split=0.25, shuffle=True,
              callbacks = callbacks.callbacks)
    # Save the model again but with the pruning 'stripped' to use the regular layer types
    model = strip_pruning(model)
    model.save('model_2/KERAS_check_best_model.h5')
else:
    from tensorflow.keras.models import load_model
    model = load_model('model_2/KERAS_check_best_model.h5')
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Train on 498000 samples, validate on 166000 samples
# Epoch 1/30
# 496640/498000 [============================>.] - ETA: 0s - loss: 1.3296 - accuracy: 0.5158
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00001: val_loss improved from inf to 1.12533, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00001: val_loss improved from inf to 1.12533, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00001: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00001: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 6s 12us/sample - loss: 1.3291 - accuracy: 0.5161 - val_loss: 1.1253 - val_accuracy: 0.6351
# Epoch 2/30
# 497664/498000 [============================>.] - ETA: 0s - loss: 1.0555 - accuracy: 0.6667
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00002: val_loss improved from 1.12533 to 1.00752, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00002: val_loss improved from 1.12533 to 1.00752, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00002: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00002: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 7us/sample - loss: 1.0554 - accuracy: 0.6667 - val_loss: 1.0075 - val_accuracy: 0.6887
# Epoch 3/30
# 492544/498000 [============================>.] - ETA: 0s - loss: 0.9721 - accuracy: 0.7000
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00003: val_loss improved from 1.00752 to 0.94500, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00003: val_loss improved from 1.00752 to 0.94500, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00003: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00003: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 7us/sample - loss: 0.9716 - accuracy: 0.7002 - val_loss: 0.9450 - val_accuracy: 0.7098
# Epoch 4/30
# 494592/498000 [============================>.] - ETA: 0s - loss: 0.9187 - accuracy: 0.7142
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00004: val_loss improved from 0.94500 to 0.90092, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00004: val_loss improved from 0.94500 to 0.90092, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00004: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00004: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.9186 - accuracy: 0.7142 - val_loss: 0.9009 - val_accuracy: 0.7187
# Epoch 5/30
# 494592/498000 [============================>.] - ETA: 0s - loss: 1.0775 - accuracy: 0.6410
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00005: val_loss did not improve from 0.90092
#
# Epoch 00005: val_loss did not improve from 0.90092
#
# Epoch 00005: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00005: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 1.0769 - accuracy: 0.6412 - val_loss: 1.0012 - val_accuracy: 0.6693
# Epoch 6/30
# 492544/498000 [============================>.] - ETA: 0s - loss: 0.9639 - accuracy: 0.6841
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00006: val_loss did not improve from 0.90092
#
# Epoch 00006: val_loss did not improve from 0.90092
#
# Epoch 00006: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00006: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.9631 - accuracy: 0.6844 - val_loss: 0.9376 - val_accuracy: 0.6948
# Epoch 7/30
# 497664/498000 [============================>.] - ETA: 0s - loss: 0.9152 - accuracy: 0.7018
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00007: val_loss improved from 0.90092 to 0.90065, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00007: val_loss improved from 0.90092 to 0.90065, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00007: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00007: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.9152 - accuracy: 0.7018 - val_loss: 0.9006 - val_accuracy: 0.7061
# Epoch 8/30
# 492544/498000 [============================>.] - ETA: 0s - loss: 0.8846 - accuracy: 0.7108
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00008: val_loss improved from 0.90065 to 0.87528, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00008: val_loss improved from 0.90065 to 0.87528, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00008: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00008: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.8845 - accuracy: 0.7108 - val_loss: 0.8753 - val_accuracy: 0.7133
# Epoch 9/30
# 492544/498000 [============================>.] - ETA: 0s - loss: 0.8632 - accuracy: 0.7165
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00009: val_loss improved from 0.87528 to 0.85797, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00009: val_loss improved from 0.87528 to 0.85797, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00009: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00009: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.8632 - accuracy: 0.7165 - val_loss: 0.8580 - val_accuracy: 0.7182
# Epoch 10/30
# 497664/498000 [============================>.] - ETA: 0s - loss: 0.8481 - accuracy: 0.7201
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00010: val_loss improved from 0.85797 to 0.84526, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00010: val_loss improved from 0.85797 to 0.84526, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00010: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00010: saving model to model_2/KERAS_check_model_last_weights.h5
#
# Epoch 00010: saving model to model_2/KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.8481 - accuracy: 0.7201 - val_loss: 0.8453 - val_accuracy: 0.7213
# Epoch 11/30
# 495616/498000 [============================>.] - ETA: 0s - loss: 0.8366 - accuracy: 0.7228
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00011: val_loss improved from 0.84526 to 0.83524, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00011: val_loss improved from 0.84526 to 0.83524, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00011: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00011: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.8367 - accuracy: 0.7228 - val_loss: 0.8352 - val_accuracy: 0.7237
# Epoch 12/30
# 494592/498000 [============================>.] - ETA: 0s - loss: 0.8274 - accuracy: 0.7252
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00012: val_loss improved from 0.83524 to 0.82714, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00012: val_loss improved from 0.83524 to 0.82714, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00012: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00012: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.8275 - accuracy: 0.7251 - val_loss: 0.8271 - val_accuracy: 0.7259
# Epoch 13/30
# 495616/498000 [============================>.] - ETA: 0s - loss: 0.8197 - accuracy: 0.7270
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00013: val_loss improved from 0.82714 to 0.82023, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00013: val_loss improved from 0.82714 to 0.82023, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00013: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00013: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.8198 - accuracy: 0.7269 - val_loss: 0.8202 - val_accuracy: 0.7273
# Epoch 14/30
# 490496/498000 [============================>.] - ETA: 0s - loss: 0.8133 - accuracy: 0.7285
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00014: val_loss improved from 0.82023 to 0.81411, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00014: val_loss improved from 0.82023 to 0.81411, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00014: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00014: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.8133 - accuracy: 0.7286 - val_loss: 0.8141 - val_accuracy: 0.7287
# Epoch 15/30
# 494592/498000 [============================>.] - ETA: 0s - loss: 0.8074 - accuracy: 0.7299
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00015: val_loss improved from 0.81411 to 0.80868, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00015: val_loss improved from 0.81411 to 0.80868, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00015: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00015: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.8073 - accuracy: 0.7300 - val_loss: 0.8087 - val_accuracy: 0.7298
# Epoch 16/30
# 494592/498000 [============================>.] - ETA: 0s - loss: 0.8020 - accuracy: 0.7313
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00016: val_loss improved from 0.80868 to 0.80363, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00016: val_loss improved from 0.80868 to 0.80363, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00016: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00016: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 7us/sample - loss: 0.8020 - accuracy: 0.7314 - val_loss: 0.8036 - val_accuracy: 0.7313
# Epoch 17/30
# 497664/498000 [============================>.] - ETA: 0s - loss: 0.7970 - accuracy: 0.7326
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00017: val_loss improved from 0.80363 to 0.79905, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00017: val_loss improved from 0.80363 to 0.79905, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00017: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00017: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.7971 - accuracy: 0.7325 - val_loss: 0.7990 - val_accuracy: 0.7325
# Epoch 18/30
# 492544/498000 [============================>.] - ETA: 0s - loss: 0.7925 - accuracy: 0.7338
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00018: val_loss improved from 0.79905 to 0.79484, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00018: val_loss improved from 0.79905 to 0.79484, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00018: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00018: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.7926 - accuracy: 0.7338 - val_loss: 0.7948 - val_accuracy: 0.7336
# Epoch 19/30
# 493568/498000 [============================>.] - ETA: 0s - loss: 0.7886 - accuracy: 0.7348
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00019: val_loss improved from 0.79484 to 0.79085, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00019: val_loss improved from 0.79484 to 0.79085, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00019: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00019: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 7us/sample - loss: 0.7884 - accuracy: 0.7349 - val_loss: 0.7909 - val_accuracy: 0.7343
# Epoch 20/30
# 495616/498000 [============================>.] - ETA: 0s - loss: 0.7844 - accuracy: 0.7360
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00020: val_loss improved from 0.79085 to 0.78707, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00020: val_loss improved from 0.79085 to 0.78707, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00020: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00020: saving model to model_2/KERAS_check_model_last_weights.h5
#
# Epoch 00020: saving model to model_2/KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.7845 - accuracy: 0.7359 - val_loss: 0.7871 - val_accuracy: 0.7353
# Epoch 21/30
# 495616/498000 [============================>.] - ETA: 0s - loss: 0.7809 - accuracy: 0.7370
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00021: val_loss improved from 0.78707 to 0.78363, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00021: val_loss improved from 0.78707 to 0.78363, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00021: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00021: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 7us/sample - loss: 0.7809 - accuracy: 0.7371 - val_loss: 0.7836 - val_accuracy: 0.7366
# Epoch 22/30
# 497664/498000 [============================>.] - ETA: 0s - loss: 0.7775 - accuracy: 0.7381
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00022: val_loss improved from 0.78363 to 0.78072, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00022: val_loss improved from 0.78363 to 0.78072, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00022: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00022: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 7us/sample - loss: 0.7775 - accuracy: 0.7381 - val_loss: 0.7807 - val_accuracy: 0.7377
# Epoch 23/30
# 497664/498000 [============================>.] - ETA: 0s - loss: 0.7744 - accuracy: 0.7391
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00023: val_loss improved from 0.78072 to 0.77761, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00023: val_loss improved from 0.78072 to 0.77761, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00023: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00023: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.7744 - accuracy: 0.7391 - val_loss: 0.7776 - val_accuracy: 0.7385
# Epoch 24/30
# 497664/498000 [============================>.] - ETA: 0s - loss: 0.7716 - accuracy: 0.7399
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00024: val_loss improved from 0.77761 to 0.77485, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00024: val_loss improved from 0.77761 to 0.77485, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00024: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00024: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.7715 - accuracy: 0.7399 - val_loss: 0.7749 - val_accuracy: 0.7393
# Epoch 25/30
# 495616/498000 [============================>.] - ETA: 0s - loss: 0.7688 - accuracy: 0.7410
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00025: val_loss improved from 0.77485 to 0.77211, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00025: val_loss improved from 0.77485 to 0.77211, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00025: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00025: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.7689 - accuracy: 0.7409 - val_loss: 0.7721 - val_accuracy: 0.7404
# Epoch 26/30
# 496640/498000 [============================>.] - ETA: 0s - loss: 0.7663 - accuracy: 0.7418
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00026: val_loss improved from 0.77211 to 0.76972, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00026: val_loss improved from 0.77211 to 0.76972, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00026: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00026: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 7us/sample - loss: 0.7663 - accuracy: 0.7418 - val_loss: 0.7697 - val_accuracy: 0.7411
# Epoch 27/30
# 492544/498000 [============================>.] - ETA: 0s - loss: 0.7639 - accuracy: 0.7426
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00027: val_loss improved from 0.76972 to 0.76746, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00027: val_loss improved from 0.76972 to 0.76746, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00027: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00027: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.7639 - accuracy: 0.7426 - val_loss: 0.7675 - val_accuracy: 0.7420
# Epoch 28/30
# 494592/498000 [============================>.] - ETA: 0s - loss: 0.7616 - accuracy: 0.7433
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00028: val_loss improved from 0.76746 to 0.76547, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00028: val_loss improved from 0.76746 to 0.76547, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00028: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00028: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.7617 - accuracy: 0.7433 - val_loss: 0.7655 - val_accuracy: 0.7426
# Epoch 29/30
# 491520/498000 [============================>.] - ETA: 0s - loss: 0.7594 - accuracy: 0.7441
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00029: val_loss improved from 0.76547 to 0.76355, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00029: val_loss improved from 0.76547 to 0.76355, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00029: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00029: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.7597 - accuracy: 0.7440 - val_loss: 0.7635 - val_accuracy: 0.7434
# Epoch 30/30
# 496640/498000 [============================>.] - ETA: 0s - loss: 0.7578 - accuracy: 0.7445
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 00030: val_loss improved from 0.76355 to 0.76183, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 00030: val_loss improved from 0.76355 to 0.76183, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 00030: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 00030: saving model to model_2/KERAS_check_model_last_weights.h5
#
# Epoch 00030: saving model to model_2/KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 498000/498000 [==============================] - 4s 8us/sample - loss: 0.7578 - accuracy: 0.7445 - val_loss: 0.7618 - val_accuracy: 0.7437

# %% [markdown]
# ## Check sparsity
# Make a quick check that the model was indeed trained sparse. We'll just make a histogram of the weights of the 1st layer, and hopefully observe a large peak in the bin containing '0'. Note logarithmic y axis.

# %%
w = model.layers[0].weights[0].numpy()
h, b = np.histogram(w, bins=100)
plt.figure(figsize=(7,7))
plt.bar(b[:-1], h, width=b[1]-b[0])
plt.semilogy()
print('% of zeros = {}'.format(np.sum(w==0)/np.size(w)))
# Out:
# % of zeros = 0.75

# %% [markdown]
# ## Check performance
# How does this 75% sparse model compare against the unpruned model? Let's report the accuracy and make a ROC curve. The pruned model is shown with solid lines, the unpruned model from part 1 is shown with dashed lines.
# **Make sure you've trained the model from part 1**

# %%
import plotting
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model
model_ref = load_model('model_1/KERAS_check_best_model.h5')

y_ref = model_ref.predict(X_test)
y_prune = model.predict(X_test)

print("Accuracy unpruned: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_ref, axis=1))))
print("Accuracy pruned:   {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_prune, axis=1))))

fig, ax = plt.subplots(figsize=(9, 9))
_ = plotting.makeRoc(y_test, y_ref, classes)
plt.gca().set_prop_cycle(None) # reset the colors
_ = plotting.makeRoc(y_test, y_prune, classes, linestyle='--')

from matplotlib.lines import Line2D
lines = [Line2D([0], [0], ls='-'),
         Line2D([0], [0], ls='--')]
from matplotlib.legend import Legend
leg = Legend(ax, lines, labels=['unpruned', 'pruned'],
            loc='lower right', frameon=False)
ax.add_artist(leg)
# Out:
# Accuracy unpruned: 0.7501024096385542
# Accuracy pruned:   0.7428373493975904

# %% [markdown]
# # Convert the model to FPGA firmware with hls4ml
# Let's use the default configuration: `ap_fixed<16,6>` precision everywhere and `ReuseFactor=1`, so we can compare with the part 1 model. We need to use `strip_pruning` to change the layer types back to their originals.
#
# **The synthesis will take a while**
#
# While the C-Synthesis is running, we can monitor the progress looking at the log file by opening a terminal from the notebook home, and executing:
#
# `tail -f model_2/hls4ml_prj/vivado_hls.log`

# %%
import hls4ml

config = hls4ml.utils.config_from_keras_model(model, granularity='model')
print(config)
hls_model = hls4ml.converters.convert_from_keras_model(model,
                                                       hls_config=config,
                                                       output_dir='model_2/hls4ml_prj',
                                                       fpga_part='xcu250-figd2104-2L-e')
hls_model.compile()
hls_model.build(csim=False)
# Out:
# Interpreting Sequential
# Topology:
# Layer name: fc1, layer type: Dense
#   -> Activation (linear), layer name: fc1
# Layer name: relu1, layer type: Activation
# Layer name: fc2, layer type: Dense
#   -> Activation (linear), layer name: fc2
# Layer name: relu2, layer type: Activation
# Layer name: fc3, layer type: Dense
#   -> Activation (linear), layer name: fc3
# Layer name: relu3, layer type: Activation
# Layer name: output, layer type: Dense
#   -> Activation (linear), layer name: output
# Layer name: softmax, layer type: Activation
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}}
# Interpreting Sequential
# Input shape: [16]
# Topology:
# Layer name: fc1, layer type: Dense, current shape: [[None, 16]]
# Layer name: relu1, layer type: Activation, current shape: [[None, 64]]
# Layer name: fc2, layer type: Dense, current shape: [[None, 64]]
# Layer name: relu2, layer type: Activation, current shape: [[None, 32]]
# Layer name: fc3, layer type: Dense, current shape: [[None, 32]]
# Layer name: relu3, layer type: Activation, current shape: [[None, 32]]
# Layer name: output, layer type: Dense, current shape: [[None, 32]]
# Layer name: softmax, layer type: Softmax, current shape: [[None, 5]]
# Creating HLS model
# Writing HLS project
# Done

# %% [markdown]
# ## Check the reports
# Print out the reports generated by Vivado HLS. Pay attention to the Utilization Estimates' section in particular this time.

# %%
hls4ml.report.read_vivado_report('model_2/hls4ml_prj/')
# Out:
# Found 1 solution(s) in model_2/hls4ml_prj//myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject'
# ================================================================
# * Date:           Fri Sep  4 09:51:03 2020
#
# * Version:        2019.2 (Build 2704478 on Wed Nov 06 22:10:23 MST 2019)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: virtexuplus
# * Target device:  xcu250-figd2104-2L-e
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing:
#     * Summary:
#     +--------+---------+----------+------------+
#     |  Clock |  Target | Estimated| Uncertainty|
#     +--------+---------+----------+------------+
#     |ap_clk  | 5.00 ns | 4.276 ns |   0.62 ns  |
#     +--------+---------+----------+------------+
#
# + Latency:
#     * Summary:
#     +---------+---------+-----------+-----------+-----+-----+----------+
#     |  Latency (cycles) |   Latency (absolute)  |  Interval | Pipeline |
#     |   min   |   max   |    min    |    max    | min | max |   Type   |
#     +---------+---------+-----------+-----------+-----+-----+----------+
#     |       16|       16| 80.000 ns | 80.000 ns |    2|    2| function |
#     +---------+---------+-----------+-----------+-----+-----+----------+
#
#     + Detail:
#         * Instance:
#         +----------------------------------+-----------------------+---------+---------+-----------+-----------+-----+-----+----------+
#         |                                  |                       |  Latency (cycles) |   Latency (absolute)  |  Interval | Pipeline |
#         |             Instance             |         Module        |   min   |   max   |    min    |    max    | min | max |   Type   |
#         +----------------------------------+-----------------------+---------+---------+-----------+-----------+-----+-----+----------+
#         |grp_dense_latency_0_0_0_1_fu_207  |dense_latency_0_0_0_1  |        2|        2| 10.000 ns | 10.000 ns |    2|    2| function |
#         |grp_dense_latency_0_0_0_s_fu_275  |dense_latency_0_0_0_s  |        2|        2| 10.000 ns | 10.000 ns |    2|    2| function |
#         |grp_dense_latency_0_0_0_2_fu_311  |dense_latency_0_0_0_2  |        1|        1|  5.000 ns |  5.000 ns |    2|    2| function |
#         |grp_dense_latency_0_0_0_3_fu_317  |dense_latency_0_0_0_3  |        2|        2| 10.000 ns | 10.000 ns |    2|    2| function |
#         |call_ret1_relu_1_fu_353           |relu_1                 |        0|        0|    0 ns   |    0 ns   |    1|    1| function |
#         |call_ret3_relu_fu_421             |relu                   |        0|        0|    0 ns   |    0 ns   |    1|    1| function |
#         |call_ret5_relu_2_fu_457           |relu_2                 |        0|        0|    0 ns   |    0 ns   |    1|    1| function |
#         +----------------------------------+-----------------------+---------+---------+-----------+-----------+-----+-----+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +---------------------+---------+-------+---------+---------+------+
# |         Name        | BRAM_18K| DSP48E|    FF   |   LUT   | URAM |
# +---------------------+---------+-------+---------+---------+------+
# |DSP                  |        -|      5|        -|        -|     -|
# |Expression           |        -|      -|        0|       78|     -|
# |FIFO                 |        -|      -|        -|        -|     -|
# |Instance             |        -|   1064|    17470|    57002|     -|
# |Memory               |        3|      -|        0|        0|     -|
# |Multiplexer          |        -|      -|        -|       99|     -|
# |Register             |        -|      -|     3991|        -|     -|
# +---------------------+---------+-------+---------+---------+------+
# |Total                |        3|   1069|    21461|    57179|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available SLR        |     1344|   3072|   864000|   432000|   320|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization SLR (%)  |    ~0   |     34|        2|       13|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available            |     5376|  12288|  3456000|  1728000|  1280|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization (%)      |    ~0   |      8|    ~0   |        3|     0|
# +---------------------+---------+-------+---------+---------+------+
#
# + Detail:
#     * Instance:
#     +----------------------------------+-----------------------+---------+-------+------+-------+-----+
#     |             Instance             |         Module        | BRAM_18K| DSP48E|  FF  |  LUT  | URAM|
#     +----------------------------------+-----------------------+---------+-------+------+-------+-----+
#     |grp_dense_latency_0_0_0_1_fu_207  |dense_latency_0_0_0_1  |        0|    512|  8772|  25264|    0|
#     |grp_dense_latency_0_0_0_2_fu_311  |dense_latency_0_0_0_2  |        0|    256|  3154|  12833|    0|
#     |grp_dense_latency_0_0_0_3_fu_317  |dense_latency_0_0_0_3  |        0|     40|  1124|   2985|    0|
#     |grp_dense_latency_0_0_0_s_fu_275  |dense_latency_0_0_0_s  |        0|    256|  4420|  12336|    0|
#     |call_ret3_relu_fu_421             |relu                   |        0|      0|     0|    896|    0|
#     |call_ret1_relu_1_fu_353           |relu_1                 |        0|      0|     0|   1792|    0|
#     |call_ret5_relu_2_fu_457           |relu_2                 |        0|      0|     0|    896|    0|
#     +----------------------------------+-----------------------+---------+-------+------+-------+-----+
#     |Total                             |                       |        0|   1064| 17470|  57002|    0|
#     +----------------------------------+-----------------------+---------+-------+------+-------+-----+

# %% [markdown]
# Print the report for the model trained in part 1. Remember these models have the same architecture, but the model in this section was trained using the sparsity API from tensorflow_model_optimization. Notice how the resource usage had dramatically reduced (particularly the DSPs). When Vivado HLS notices an operation like `y = 0 * x` it can avoid placing a DSP for that operation. The impact of this is biggest when `ReuseFactor = 1`, but still applies at higher reuse as well. **Note you need to have trained and synthesized the model from part 1**

# %%
hls4ml.report.read_vivado_report('model_1/hls4ml_prj')
# Out:
# Found 1 solution(s) in model_1/hls4ml_prj/myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject'
# ================================================================
# * Date:           Fri Sep  4 08:47:39 2020
#
# * Version:        2019.2 (Build 2704478 on Wed Nov 06 22:10:23 MST 2019)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: virtexuplus
# * Target device:  xcu250-figd2104-2L-e
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing:
#     * Summary:
#     +--------+---------+----------+------------+
#     |  Clock |  Target | Estimated| Uncertainty|
#     +--------+---------+----------+------------+
#     |ap_clk  | 5.00 ns | 3.883 ns |   0.62 ns  |
#     +--------+---------+----------+------------+
#
# + Latency:
#     * Summary:
#     +---------+---------+-----------+-----------+-----+-----+----------+
#     |  Latency (cycles) |   Latency (absolute)  |  Interval | Pipeline |
#     |   min   |   max   |    min    |    max    | min | max |   Type   |
#     +---------+---------+-----------+-----------+-----+-----+----------+
#     |        9|        9| 45.000 ns | 45.000 ns |    1|    1| function |
#     +---------+---------+-----------+-----------+-----+-----+----------+
#
#     + Detail:
#         * Instance:
#         +----------------------------------+-----------------------+---------+---------+----------+----------+-----+-----+----------+
#         |                                  |                       |  Latency (cycles) |  Latency (absolute) |  Interval | Pipeline |
#         |             Instance             |         Module        |   min   |   max   |    min   |    max   | min | max |   Type   |
#         +----------------------------------+-----------------------+---------+---------+----------+----------+-----+-----+----------+
#         |grp_dense_latency_0_0_0_1_fu_215  |dense_latency_0_0_0_1  |        1|        1| 5.000 ns | 5.000 ns |    1|    1| function |
#         |grp_dense_latency_0_0_0_s_fu_283  |dense_latency_0_0_0_s  |        1|        1| 5.000 ns | 5.000 ns |    1|    1| function |
#         |grp_dense_latency_0_0_0_2_fu_319  |dense_latency_0_0_0_2  |        1|        1| 5.000 ns | 5.000 ns |    1|    1| function |
#         |grp_dense_latency_0_0_0_3_fu_325  |dense_latency_0_0_0_3  |        1|        1| 5.000 ns | 5.000 ns |    1|    1| function |
#         |call_ret1_relu_1_fu_361           |relu_1                 |        0|        0|   0 ns   |   0 ns   |    1|    1| function |
#         |call_ret3_relu_fu_429             |relu                   |        0|        0|   0 ns   |   0 ns   |    1|    1| function |
#         |call_ret5_relu_2_fu_465           |relu_2                 |        0|        0|   0 ns   |   0 ns   |    1|    1| function |
#         +----------------------------------+-----------------------+---------+---------+----------+----------+-----+-----+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +---------------------+---------+-------+---------+---------+------+
# |         Name        | BRAM_18K| DSP48E|    FF   |   LUT   | URAM |
# +---------------------+---------+-------+---------+---------+------+
# |DSP                  |        -|      5|        -|        -|     -|
# |Expression           |        -|      -|        0|       78|     -|
# |FIFO                 |        -|      -|        -|        -|     -|
# |Instance             |        -|   3948|    24516|    78497|     -|
# |Memory               |        4|      -|        0|        0|     -|
# |Multiplexer          |        -|      -|        -|       36|     -|
# |Register             |        -|      -|     2405|        -|     -|
# +---------------------+---------+-------+---------+---------+------+
# |Total                |        4|   3953|    26921|    78611|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available SLR        |     1344|   3072|   864000|   432000|   320|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization SLR (%)  |    ~0   |    128|        3|       18|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available            |     5376|  12288|  3456000|  1728000|  1280|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization (%)      |    ~0   |     32|    ~0   |        4|     0|
# +---------------------+---------+-------+---------+---------+------+
#
# + Detail:
#     * Instance:
#     +----------------------------------+-----------------------+---------+-------+-------+-------+-----+
#     |             Instance             |         Module        | BRAM_18K| DSP48E|   FF  |  LUT  | URAM|
#     +----------------------------------+-----------------------+---------+-------+-------+-------+-----+
#     |grp_dense_latency_0_0_0_1_fu_215  |dense_latency_0_0_0_1  |        0|   1858|  11265|  35808|    0|
#     |grp_dense_latency_0_0_0_2_fu_319  |dense_latency_0_0_0_2  |        0|    983|   6145|  18240|    0|
#     |grp_dense_latency_0_0_0_3_fu_325  |dense_latency_0_0_0_3  |        0|    160|    961|   2825|    0|
#     |grp_dense_latency_0_0_0_s_fu_283  |dense_latency_0_0_0_s  |        0|    947|   6145|  18040|    0|
#     |call_ret3_relu_fu_429             |relu                   |        0|      0|      0|    896|    0|
#     |call_ret1_relu_1_fu_361           |relu_1                 |        0|      0|      0|   1792|    0|
#     |call_ret5_relu_2_fu_465           |relu_2                 |        0|      0|      0|    896|    0|
#     +----------------------------------+-----------------------+---------+-------+-------+-------+-----+
#     |Total                             |                       |        0|   3948|  24516|  78497|    0|
#     +----------------------------------+-----------------------+---------+-------+-------+-------+-----+
